# %% [markdown]
# K-Means Clustering is an Unsupervised Learning algorithm, which groups the unlabeled dataset into different clusters. Here K defines the number of pre-defined clusters that need to be created in the process, as if K=2, there will be two clusters, and for K=3, there will be three clusters, and so on.
#
# It is an iterative algorithm that divides the unlabeled dataset into k different clusters in such a way that each dataset belongs only one group that has similar properties.
# It allows us to cluster the data into different groups and a convenient way to discover the categories of groups in the unlabeled dataset on its own without the need for any training.
#
# It is a centroid-based algorithm, where each cluster is associated with a centroid. The main aim of this algorithm is to minimize the sum of distances between the data point and their corresponding clusters.
# The algorithm takes the unlabeled dataset as input, divides the dataset into k-number of clusters, and repeats the process until it does not find the best clusters. The value of k should be predetermined in this algorithm.
#
# The k-means clustering algorithm mainly performs two tasks:
#
# Determines the best value for K center points or centroids by an iterative process.
# Assigns each data point to its closest k-center. Those data points which are near to the particular k-center, create a cluster.
# Hence each cluster has datapoints with some commonalities, and it is away from other clusters.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Applications of clustering
#
# K-Means clustering is the most common unsupervised machine learning algorithm. It is widely used for many applications which include-
#
# Image segmentation
#
# Customer segmentation
#
# Species clustering
#
# Anomaly detection
#
# Clustering languages

# %% [markdown]
# How to Implementing K-Means Clustering ?
#
# 1.Choose the number of clusters k
#
# 2.Select k random points from the data as centroids
#
# 3.Assign all the points to the closest cluster centroid
#
# 4.Recompute the centroids of newly formed clusters
# Repeat steps 3 and 4

# %% [markdown]
#  Here's an example code snippet using plot_decision_regions with K-means clustering:

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import warnings
warnings.filterwarnings('ignore')
# Generate some synthetic data
X, y = make_blobs(n_samples=300, centers=4, random_state=42)

# Apply K-means clustering
kmeans = KMeans(n_clusters=4, random_state=42)
kmeans.fit(X)

# Plot decision regions
plt.figure(figsize=(10, 6))
plot_decision_regions(X, kmeans.labels_, clf=kmeans, legend=4)
plt.title('K-means Clustering Decision Regions')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.cluster import KMeans 
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import MinMaxScaler

# %%
iris=pd.read_csv("iris.csv")
x=iris.iloc[:,[0,1,2,3]].values

# %%
iris.info()
iris[0:10]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# ...

# %%
iris_outcome = pd.crosstab(index=iris["species"], columns="count")

# Display the frequency distribution
print("Frequency distribution of species:")
iris_outcome
# Out:
# Frequency distribution of species:
# col_0            count
# species
# Iris-setosa         50
# Iris-versicolor     50
# Iris-virginica      50

# %%
iris_setosa = iris.loc[iris["species"] == "Iris-setosa"]
iris_virginica = iris.loc[iris["species"] == "Iris-virginica"]
iris_versicolor = iris.loc[iris["species"] == "Iris-versicolor"]
# Display the first few rows of each filtered DataFrame for verification
print("Iris Setosa:")
iris_setosa.head()
print("\nIris Virginica:")
iris_virginica.head()
print("\nIris Versicolor:")
iris_versicolor.head()
# Out:
# Iris Setosa:
#
# Iris Virginica:
#
# Iris Versicolor:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 50           7.0          3.2           4.7          1.4  Iris-versicolor
# 51           6.4          3.2           4.5          1.5  Iris-versicolor
# 52           6.9          3.1           4.9          1.5  Iris-versicolor
# 53           5.5          2.3           4.0          1.3  Iris-versicolor
# 54           6.5          2.8           4.6          1.5  Iris-versicolor

# %%
import warnings
warnings.filterwarnings('ignore')
# Create a FacetGrid for each attribute
grid_petal_length = sns.FacetGrid(iris, hue="species", height=3)
grid_petal_width = sns.FacetGrid(iris, hue="species", height=3)
grid_sepal_length = sns.FacetGrid(iris, hue="species", height=3)

# Map a distribution plot for each attribute
grid_petal_length.map(sns.distplot, "petal_length").add_legend()
grid_petal_width.map(sns.distplot, "petal_width").add_legend()
grid_sepal_length.map(sns.distplot, "sepal_length").add_legend()

# Display the plots
plt.show()

# %%
sns.boxplot(x="species",y="petal_length",data=iris)
plt.show()

# %%
#violinplot
sns.violinplot(x="species",y="petal_length",data=iris)
plt.show()

# %%
# Visualize feature distributions
sns.set_style("whitegrid")
sns.pairplot(iris,hue="species",size=3);
plt.show()

# %%
# Display basic statistics
iris.describe()

# Check for missing values
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Box plot for sepal length
sns.boxplot(x='species', y='sepal_length', data=iris)
plt.show()

# %%
# Box plot for sepal width
sns.boxplot(x='species', y='sepal_width', data=iris)
plt.show()

# %%
sns.boxplot(x="species",y="petal_width",data=iris)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_features = scaler.fit_transform(iris.drop('species', axis=1))

# %% [markdown]
# K-Means Clustering

# %% [markdown]
# Using the elbow method to determine the optimal number of clusters for k-means clustering.

# %%
from sklearn.cluster import KMeans

def find_optimal_k(data, max_k=10):
    wcss = []
    
    for i in range(1, max_k + 1):
        kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
        kmeans.fit(data)
        wcss.append(kmeans.inertia_)
    
    return wcss

def plot_elbow(wcss, max_k=10):
    plt.plot(range(1, max_k + 1), wcss, marker='o')
    plt.title('Elbow Method for Optimal k')
    plt.xlabel('Number of Clusters (k)')
    plt.ylabel('Within-Cluster Sum of Squares (WCSS)')
    plt.show()

# Assuming x is your dataset
wcss_values = find_optimal_k(x)
plot_elbow(wcss_values)

# %% [markdown]
# Implementing K-Means Clustering

# %%
from sklearn.cluster import KMeans
# Creating a KMeans instance with specified parameters
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, n_init=10, random_state=0)
# Fitting the KMeans model to the data and obtaining cluster assignments
y_kmeans = kmeans.fit_predict(x)

# %%
#Visualising the clusters
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], s = 100, c = 'purple', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], s = 100, c = 'orange', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Iris-virginica')

#Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'red', label = 'Centroids')

plt.legend()

# %%
from mpl_toolkits.mplot3d import Axes3D
# Create a 3D scatter plot
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot(111, projection='3d')
# Scatter plot for each cluster
for cluster_label, color, label in zip(range(3), ['purple', 'orange', 'green'], ['Iris-setosa', 'Iris-versicolour', 'Iris-virginica']):
    ax.scatter(x[y_kmeans == cluster_label, 0], x[y_kmeans == cluster_label, 1], x[y_kmeans == cluster_label, 2],
               s=100, c=color, label=label)
# Plotting the centroids of the clusters
ax.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], kmeans.cluster_centers_[:, 2],
           s=100, c='red', label='Centroids')
# Set labels and legend
ax.set_xlabel('Sepal Length (cm)')
ax.set_ylabel('Sepal Width (cm)')
ax.set_zlabel('Petal Length (cm)')
ax.legend()# Show the plot
plt.show()
